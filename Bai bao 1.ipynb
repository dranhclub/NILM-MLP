# %% [markdown]
# # Import thư viện

# %%
# Pandas for reading data
import pandas as pd

# Matplotlib for ploting graph
import matplotlib.pyplot as plt

# Train test split
from sklearn.model_selection import train_test_split

# Multilayer Perceptron Classifier
from sklearn.neural_network import MLPClassifier

# %% [markdown]
# # Đọc dữ liệu

# %%
# Power dataframe
p_df = pd.read_csv('./data/W.csv',\
                       names=['time', 'light', 'socket', 'heater', 'aircond1', 'aircond2', 'aircond3', 'indcooker'],\
                       header=0)

# Voltage dataframe
u_df = pd.read_csv('./data/V.csv',\
                  names=['time', 'u'],\
                  header=0)

# Current dataframe
i_df = pd.read_csv('./data/A.csv',\
                  names=['time', 'light', 'socket', 'heater', 'aircond1', 'aircond2', 'aircond3', 'indcooker'],\
                  header=0)

# %% [markdown]
# light    : chiếu sáng
# socket   : ổ cắm phòng khách + bếp + ngủ
# heater   : bình nóng lạnh
# aircond1 : điều hoà 1 & 2
# aircond2 : điều hoà 3
# aircond3 : điều hoà phòng khách
# indcooker: bếp từ

# %% [markdown]
# ### Bảng đo công suất tiêu thụ

# %%
p_df
# Out:
#                       time  light  socket  heater  aircond1  aircond2  \
# 0      2020-07-15 00:00:00    0.0   216.0       0     244.0       0.0
# 1      2020-07-15 00:01:00    0.0   210.0       0     286.0       0.0
# 2      2020-07-15 00:02:00    0.0   206.0       0     314.0       0.0
# 3      2020-07-15 00:03:00    0.0   206.0       0     254.0       0.0
# 4      2020-07-15 00:04:00    0.0   160.0       0     274.0       0.0
# ...                    ...    ...     ...     ...       ...       ...
# 31675  2020-08-05 23:55:00    0.0   236.0       0     183.0       0.0
# 31676  2020-08-05 23:56:00    0.0   238.0       0     174.0       0.0
# 31677  2020-08-05 23:57:00    0.0   243.0       0     199.0       0.0
# 31678  2020-08-05 23:58:00    0.0   241.0       0     229.0       0.0
# 31679  2020-08-05 23:59:00    0.0   246.0       0     245.0       0.0
#
#        aircond3  indcooker
# 0         631.0        1.0
# 1         631.0        3.5
# 2         633.0        6.0
# 3         632.0        3.5
# 4         629.0        1.0
# ...         ...        ...
# 31675       0.0        1.0
# 31676       0.0        1.0
# 31677       0.0        1.0
# 31678       0.0        1.0
# 31679       0.0        1.0
#
# [31680 rows x 8 columns]

# %% [markdown]
# ### Bảng đo điện áp tiêu thụ

# %%
u_df
# Out:
#                       time    u
# 0      2020-07-15 00:00:00  231
# 1      2020-07-15 00:01:00  230
# 2      2020-07-15 00:02:00  230
# 3      2020-07-15 00:03:00  230
# 4      2020-07-15 00:04:00  230
# ...                    ...  ...
# 31675  2020-08-05 23:55:00  230
# 31676  2020-08-05 23:56:00  230
# 31677  2020-08-05 23:57:00  231
# 31678  2020-08-05 23:58:00  231
# 31679  2020-08-05 23:59:00  232
#
# [31680 rows x 2 columns]

# %% [markdown]
# ### Bảng đo dòng điện tiêu thụ

# %%
i_df
# Out:
#                       time  light  socket  heater  aircond1  aircond2  \
# 0      2020-07-15 00:00:00    0.0   0.965     0.0      1.52       0.0
# 1      2020-07-15 00:01:00    0.0   0.955     0.0      1.53       0.0
# 2      2020-07-15 00:02:00    0.0   0.950     0.0      1.53       0.0
# 3      2020-07-15 00:03:00    0.0   0.950     0.0      1.53       0.0
# 4      2020-07-15 00:04:00    0.0   0.790     0.0      1.53       0.0
# ...                    ...    ...     ...     ...       ...       ...
# 31675  2020-08-05 23:55:00    0.0   1.060     0.0      1.17       0.0
# 31676  2020-08-05 23:56:00    0.0   1.060     0.0      1.17       0.0
# 31677  2020-08-05 23:57:00    0.0   1.070     0.0      1.17       0.0
# 31678  2020-08-05 23:58:00    0.0   1.070     0.0      1.17       0.0
# 31679  2020-08-05 23:59:00    0.0   1.080     0.0      1.16       0.0
#
#        aircond3  indcooker
# 0          2.86       0.25
# 1          2.86       0.25
# 2          2.86       0.25
# 3          2.87       0.25
# 4          2.86       0.25
# ...         ...        ...
# 31675      0.00       0.25
# 31676      0.00       0.25
# 31677      0.00       0.25
# 31678      0.00       0.25
# 31679      0.00       0.25
#
# [31680 rows x 8 columns]

# %% [markdown]
# # Chuẩn bị dữ liệu

# %% [markdown]
# ### Chọn các thiết bị sẽ phân loại

# %%
select_device = ['heater', 'indcooker']
# select_device = ['heater', 'indcooker', 'aircond1']
# select_device = ['heater', 'indcooker', 'aircond1', 'aircond2', 'aircond3']
# select_device = ['heater', 'indcooker', 'aircond1', 'aircond2', 'aircond3', 'socket', 'light']

# %% [markdown]
# ### Tính tổng P

# %%
p_df['sum'] = p_df[select_device].sum(axis=1)
p_df.head()
# Out:
#                   time  light  socket  heater  aircond1  aircond2  aircond3  \
# 0  2020-07-15 00:00:00    0.0   216.0       0     244.0       0.0     631.0
# 1  2020-07-15 00:01:00    0.0   210.0       0     286.0       0.0     631.0
# 2  2020-07-15 00:02:00    0.0   206.0       0     314.0       0.0     633.0
# 3  2020-07-15 00:03:00    0.0   206.0       0     254.0       0.0     632.0
# 4  2020-07-15 00:04:00    0.0   160.0       0     274.0       0.0     629.0
#
#    indcooker     sum
# 0        1.0  1092.0
# 1        3.5  1130.5
# 2        6.0  1159.0
# 3        3.5  1095.5
# 4        1.0  1064.0

# %% [markdown]
# ### Tính tổng I

# %%
i_df['sum'] = i_df[select_device].sum(axis=1)
i_df.head()
# Out:
#                   time  light  socket  heater  aircond1  aircond2  aircond3  \
# 0  2020-07-15 00:00:00    0.0   0.965     0.0      1.52       0.0      2.86
# 1  2020-07-15 00:01:00    0.0   0.955     0.0      1.53       0.0      2.86
# 2  2020-07-15 00:02:00    0.0   0.950     0.0      1.53       0.0      2.86
# 3  2020-07-15 00:03:00    0.0   0.950     0.0      1.53       0.0      2.87
# 4  2020-07-15 00:04:00    0.0   0.790     0.0      1.53       0.0      2.86
#
#    indcooker    sum
# 0       0.25  5.595
# 1       0.25  5.595
# 2       0.25  5.590
# 3       0.25  5.600
# 4       0.25  5.430

# %% [markdown]
# ### Gán nhãn

# %% [markdown]
# Dựa vào bảng đo công suất tiêu thụ, tại một thời điểm t, thiết bị nào có công suất tiêu thụ lớn hơn `threshold` thì xác định là thiết bị đó đang bật.
#
# Có n thiết bị thì sẽ có tương ứng 2^n trường hợp, hay 2^n nhãn lớp.
#
# Ví dụ có 5 thiết bị: A, B, C, D, E:
# - A đang bật => 1
# - B đang tắt => 0
# - C đang bật => 1
# - D đang bật => 1
# - E đang tắt => 0
#
# Thì nhãn lớp sẽ là 10110 (base 2) tương ứng với 22 (base 10)

# %%
threshold = 10

def set_label(row):
    x = 0
    for i, name in enumerate(select_device):
        if row[name] > 10:
            x += 2**i
    return x

p_df['label'] = p_df.apply(set_label, axis=1)

p_df.sample(10)
# Out:
#                       time  light  socket  heater  aircond1  aircond2  \
# 1597   2020-07-16 02:37:00    0.0   101.0       0     241.0       0.0
# 14613  2020-07-25 03:33:00    0.0   257.0       0       0.0     484.0
# 1497   2020-07-16 00:57:00    0.0   209.0       0     364.0       0.0
# 16834  2020-07-26 16:34:00    8.5   733.0       0       0.0       0.0
# 22261  2020-07-30 11:01:00   16.5   321.0       0       0.0       0.0
# 18776  2020-07-28 00:56:00    0.0   236.0       0     150.0       0.0
# 15682  2020-07-25 21:22:00   10.5   301.0       0       0.0       0.0
# 23578  2020-07-31 08:58:00  128.0   250.0       0       0.0       0.0
# 8371   2020-07-20 19:31:00   22.0    28.0       0       0.0       0.0
# 10122  2020-07-22 00:42:00    0.0   239.0       0     285.0       0.0
#
#        aircond3  indcooker     sum  label
# 1597      620.0        1.0   963.0     52
# 14613      32.0        1.0   774.0     56
# 1497      627.0        1.0  1201.0     52
# 16834    2025.0        1.0  2767.5     48
# 22261    1344.0        2.5  1684.0    112
# 18776     596.0        1.0   983.0     52
# 15682    2049.0        1.0  2361.5    112
# 23578    1107.0        1.5  1486.5    112
# 8371        0.0        0.5    50.5     96
# 10122     620.0        1.0  1145.0     52

# %% [markdown]
# ### Lấy các cột tổng ra cùng với label tương ứng

# %%
data = pd.DataFrame()
data['P'] = p_df['sum']
data['U'] = u_df['u']
data['I'] = i_df['sum'] * 100  # Nhân 100 để I không quá nhỏ so với các đại lượng khác
data['Label'] = p_df['label']

data.sample(10)
# Out:
#             P    U       I  Label
# 1718   1137.0  228   542.0     52
# 4601   1015.0  230   545.0     52
# 9422   2155.0  223   988.0     48
# 18626  1741.0  225   825.0     52
# 3582   2296.0  223  1054.0     48
# 11856   270.5  233   204.0     36
# 4468   1209.5  229   625.0     52
# 13160  1102.0  230   532.0     52
# 4949    119.0  227    90.0     32
# 2686   2236.0  226  1035.5    112

# %% [markdown]
# ### Đưa về tập X và y để đưa vào model

# %% [markdown]
# Tập dữ liệu X phải chuẩn hoá về ma trận 2 chiều của numpy
# Mỗi dòng tương ứng với một điểm dữ liệu

# %%
X = data[['P', 'U', 'I']].to_numpy()

# %% [markdown]
# #### Tập nhãn lớp y đưa về dạng one-hot-coding vector
# Ví dụ:
# - label = 0 tương ứng với vector [1, 0, 0, ..., 0]
# - label = 1 tương ứng với vector [0, 1, 0, ..., 0]
# - label = 2 tương ứng với vector [0, 0, 1, ..., 0]
# - ...
# - label = 2^n - 1 (n = số thiết bị) tương ứng với vector [0, 0, 0, ..., 1]
#
# Số lượng nơ-ron ở tầng đầu ra = độ dài vector output = 2 ^ n

# %%
y = [[0 for i in range(2**len(select_device))] for j in range(len(data))]
for i in range(len(data)):
    y[i][data['Label'][i]] = 1

# %% [markdown]
# #### Cách khác để mã hoá nhãn lớp (không làm theo bài báo):

# %% [markdown]
# Vì cách mã hoá one-hot-coding sẽ khiến vector output có độ dài bằng 2^n, sẽ làm tầng output của mạng nơ-ron cồng kềnh dẫn đến mất thời gian tính toán, nên có một cách khác tự nhiên hơn. (Thử nghiệm cho thấy độ hiệu quả là xấp xỉ nhau)
#
# Giữ nhãn lớp ở dạng vector gồm 1 và 0 tương ứng với trạng thái của các thiết bị.
# Ví dụ có 5 thiết bị: A, B, C, D, E:
# - A đang bật => 1
# - B đang tắt => 0
# - C đang bật => 1
# - D đang bật => 1
# - E đang tắt => 0
#
# Thì mã hoá nhãn lớp là vector [1,0,1,1,0] luôn.
#
# Số lượng nơ ron ở tầng đầu ra = số thiết bị cần phân loại.

# %%
# def tobase2(n):
#     length = len(select_device)
#     ret = [0 for i in range(length)]
#     i = length - 1
#     while n > 0:
#         ret[i] = n % 2
#         n = n // 2
#         i -= 1
#     return ret

# y = [tobase2(data['Label'][i]) for i in range(len(data))]

# %% [markdown]
# # Đưa dữ liệu vào mô hình

# %% [markdown]
# ### Chia tập train, test
#
# Tỷ lệ chia 70-30, lấy theo thứ tự, không xáo trộn (để dễ dàng so sánh kết quả với các giải thuật hoặc mô hình khác)

# %%
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.3, random_state=1, shuffle=False)

# %% [markdown]
# ### Train

# %%
clf = MLPClassifier(solver='adam', 
                    alpha=1e-5, 
                    hidden_layer_sizes=100, 
                    random_state=1, 
                    max_iter=1000, 
                    verbose=True, 
                    learning_rate='adaptive',
                    n_iter_no_change=20)
clf.fit(X_train, y_train)
# Out:
# Iteration 1, loss = 178.78572107
# Iteration 2, loss = 5.00006430
# Iteration 3, loss = 3.78100743
# Iteration 4, loss = 3.31526946
# Iteration 5, loss = 3.17682624
# Iteration 6, loss = 3.20308830
# Iteration 7, loss = 3.10159908
# Iteration 8, loss = 3.22212831
# Iteration 9, loss = 3.21151260
# Iteration 10, loss = 3.03639630
# Iteration 11, loss = 2.97848580
# Iteration 12, loss = 3.16993094
# Iteration 13, loss = 3.03449372
# Iteration 14, loss = 3.04604390
# Iteration 15, loss = 3.02938414
# Iteration 16, loss = 3.31733322
# Iteration 17, loss = 3.02229443
# Iteration 18, loss = 3.04434685
# Iteration 19, loss = 2.91768013
# Iteration 20, loss = 2.99473837
# Iteration 21, loss = 2.89667920
# Iteration 22, loss = 3.02632896
# Iteration 23, loss = 2.78349442
# Iteration 24, loss = 2.88178258
# Iteration 25, loss = 2.84928142
# Iteration 26, loss = 2.90689212
# Iteration 27, loss = 2.92421764
# Iteration 28, loss = 3.07242460
# Iteration 29, loss = 2.96170760
# Iteration 30, loss = 3.01568472
# Iteration 31, loss = 2.94865357
# Iteration 32, loss = 2.97745675
# Iteration 33, loss = 3.14651157
# Iteration 34, loss = 2.93452556
# Iteration 374, loss = 1.96162780
# Iteration 375, loss = 1.95383636
# Iteration 376, loss = 1.94819398
# Iteration 377, loss = 1.95491991
# Iteration 378, loss = 1.96023542
# Iteration 379, loss = 1.95746228
# Iteration 380, loss = 1.96731674
# Iteration 381, loss = 1.96091808
# Iteration 382, loss = 1.94440441
# Iteration 383, loss = 1.94882202
# Iteration 384, loss = 1.96041284
# Iteration 385, loss = 1.94832129
# Iteration 386, loss = 1.94536917
# Iteration 387, loss = 1.94634246
# Iteration 388, loss = 1.95592848
# Iteration 389, loss = 1.95302805
# Iteration 390, loss = 1.94833777
# Iteration 391, loss = 1.95381611
# Iteration 392, loss = 1.95594885
# Iteration 393, loss = 1.95463454
# Iteration 394, loss = 1.95590189
# Iteration 395, loss = 1.95036518
# Iteration 396, loss = 1.95682334
# Iteration 397, loss = 1.94729816
# Iteration 398, loss = 1.95751262
# Iteration 399, loss = 1.95268587
# Iteration 400, loss = 1.96074259
# Iteration 401, loss = 1.94773478
# Iteration 402, loss = 1.94848035
# Iteration 403, loss = 1.94186837
# Iteration 404, loss = 1.95564940
# Iteration 405, loss = 1.95282997
# Iteration 406, loss = 1.95005527
# Iteration 407, loss = 1.94904220
# Iteration 408, loss = 1.94144730
# Iteration 409, loss = 1.94733701
# Iteration 410, loss = 1.93927649
# Iteration 411, loss = 1.95207910
# Iteration 412, loss = 1.94820542
# Iteration 413, loss = 1.94829048
# Iteration 414, loss = 1.94249012
# Iteration 415, loss = 1.94940378
# Iteration 416, loss = 1.95860695
# Iteration 417, loss = 1.94973044
# Iteration 418, loss = 1.94908155
# Iteration 419, loss = 1.94511027
# Iteration 420, loss = 1.95069162
# Iteration 421, loss = 1.94759683
# Iteration 422, loss = 1.94692006
# Iteration 423, loss = 1.94437941
# Iteration 424, loss = 1.94724191
# Iteration 425, loss = 1.95525178
# Iteration 426, loss = 1.93715840
# Iteration 427, loss = 1.93960333
# Iteration 428, loss = 1.93716683
# Iteration 429, loss = 1.94828200
# Iteration 430, loss = 1.95674515
# Iteration 431, loss = 1.93742136
# Iteration 432, loss = 1.94780266
# Iteration 433, loss = 1.95349444
# Iteration 434, loss = 1.94892307
# Iteration 435, loss = 1.94702540
# Iteration 436, loss = 1.94068137
# Iteration 437, loss = 1.94329013
# Iteration 438, loss = 1.94555523
# Iteration 439, loss = 1.93879645
# Iteration 440, loss = 1.94498203
# Iteration 441, loss = 1.94475082
# Iteration 442, loss = 1.95611382
# Iteration 443, loss = 1.95690355
# Iteration 444, loss = 1.95321367
# Iteration 445, loss = 1.94743216
# Iteration 446, loss = 1.94013060
# Iteration 447, loss = 1.95029161
# Training loss did not improve more than tol=0.000100 for 20 consecutive epochs. Stopping.
# MLPClassifier(alpha=1e-05, hidden_layer_sizes=100, learning_rate='adaptive',
#               max_iter=1000, n_iter_no_change=20, random_state=1, verbose=True)

# %% [markdown]
# ### Test

# %% [markdown]
# Độ chính xác của mô hình

# %%
clf.score(X_test, y_test)
# Out:
# 0.2770412457912458
